# %% [markdown]
# <a href="https://colab.research.google.com/github/michael-fawzy/ALX-T-Data-Analyst/blob/main/Wine_Quality_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Table of contents
#
# [1. Asking Quesetions](#questions)
#
# [2. Gathering](#Gathering)
#
# [3. Assessing](#Assessing)
#
# [4. Appending Data](#Appending)
#   * [Create Color Columns](#create_columns)
#
#   * [Combine DataFrames with Append](#combine_dataframes)
#
#   * [Save Combined Dataset](#save_combined)
#
# [5. EDA with Visuals](#EDA)
#
# [6. Drawing Conclusions Using Groupby](#group_by)
#
# [7. Drawing Conclusions Using Query](#query)
#
# [8. Plotting with Matplotlib](#plt)
#
# [9. Plotting Wine Type and Quality with Matplotlib](#plt2)

# %% [markdown]
# <a id='questions'></a>
# # Asking Questions
#
# 1. What chemical characteristics are most important in predicting the quality of wine?
#
# 2. Is a certain type of wine (red or white) associated with higher quality?
#
# 3. Do wines with higher alcoholic content receive better ratings?
#
# 4. Do sweeter wines (more residual sugar) receive better ratings?
#
# 5. What level of acidity is associated with the highest quality?

# %% [markdown]
# # Gathering
# Load the required libraries and read the csv files

# %%
# Import the required libraries:

# pandas
import pandas as pd
# numpy

# matplotlib.pyplot

# seaborn

#sns.set_style('darkgrid')

#%matplotlib inline

# %%
# Read the winequality-red.csv
red_df = pd.read_csv('winequality-red.csv', sep = ';')

# %%
# Read the winequality-white.csv
white_df =

# %% [markdown]
# # Assessing
# Use the space below to explore `winequality-red.csv` and `winequality-white.csv`.

# %%
# View first five lines of red_df
red_df.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur-dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
# Number of columns and rows in red_df
red_df.shape
# Out:
# (1599, 12)

# %%
# View first five lines of white_df

# %%
# Number of columns and rows in white_df

# %%
# View null values in red_df
red_df.isnull().sum()
# Out:
# fixed_acidity           0
# volatile_acidity        0
# citric_acid             0
# residual_sugar          0
# chlorides               0
# free_sulfur_dioxide     0
# total_sulfur-dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
# View null values in white_df

# %%
# info() can simply summarize all the previous infromation in one command

# view info of red_df
red_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed_acidity         1599 non-null   float64
#  1   volatile_acidity      1599 non-null   float64
#  2   citric_acid           1599 non-null   float64
#  3   residual_sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free_sulfur_dioxide   1599 non-null   float64
#  6   total_sulfur-dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
# view info of white_df

# %%
# check for duplicates in red_df
red_df.duplicated().sum()
# Out:
# 240

# %%
# check for duplicates in white_df

# %%
# View number of unique values in red_df 
red_df.nunique()
# Out:
# fixed_acidity            96
# volatile_acidity        143
# citric_acid              80
# residual_sugar           91
# chlorides               153
# free_sulfur_dioxide      60
# total_sulfur-dioxide    144
# density                 436
# pH                       89
# sulphates                96
# alcohol                  65
# quality                   6
# dtype: int64

# %%
# View number of unique values in white_df

# %%
# Mean density of the red wine dataset
red_df['density'].mean()
# Out:
# 0.9967466791744831

# %%
# Mean density of the white wine dataset

# %% [markdown]
# <a id='Appending'></a>
# # Appending Data

# %% [markdown]
# <a id='create_columns'></a>
# ## Create Color Columns
# Create two arrays as long as the number of rows in the red and white dataframes that repeat the value “red” or “white.” NumPy offers really easy way to do this. Here’s the documentation for [NumPy’s repeat](https://docs.scipy.org/doc/numpy/reference/generated/numpy.repeat.html) function. Take a look and try it yourself.

# %%
# create color array for red dataframe
color_red = np.repeat('red', 1599)

# %%
color_red
# Out:
# array(['red', 'red', 'red', ..., 'red', 'red', 'red'], dtype='<U3')

# %%
# create color array for white dataframe containing the word "white"

# %% [markdown]
# Add arrays to the red and white dataframes. Do this by setting a new column called 'color' to the appropriate array. The cell below does this for the red dataframe.

# %%
# An easier way is just to assign a value to the new column
# re_df['color'] = 'red'

# %%
red_df['color'] = color_red
red_df.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur-dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality color
# 0      9.4        5   red
# 1      9.8        5   red
# ...

# %% [markdown]
# Do the same for the white dataframe and use `head()` to confirm the change.

# %%
# Add array to the white dataframes

# %% [markdown]
# <a id='combine_dataframes'></a>
# ## Combine DataFrames with Append
# Check the documentation for [Pandas' append](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.append.html) function and see if you can use this to figure out how to combine the dataframes. (Bonus: Why aren't we using the [merge](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.merge.html) method to combine the dataframes?) If you don’t get it, I’ll show you how afterwards. Make sure to save your work in this notebook! You'll come back to this later.

# %%
# Rename total_sulfur-dioxide column to match the corresponding column name in the white wine dataset
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
# append dataframes
wine_df = red_df.append(white_df)

# view dataframe to check for success
wine_df.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality color
# 0      9.4        5   red
# 1      9.8        5   red
# ...

# %%
# Check shape of wine_df. Make sure you have only 13 columns

# %% [markdown]
# <a id='save_combined'></a>
# ## Save Combined Dataset
# Save your newly combined dataframe as `winequality_edited.csv`. Remember, set `index=False` to avoid saving with an unnamed column!

# %%
wine_df.to_csv('winequality_edited.csv', index=False)

# %% [markdown]
# <a id='EDA'></a>
# # EDA with Visuals
# Create visualizations to answer the quiz questions below. Use the `winequality_edited.csv` dataset, which you should've created  in the previous concept: *Appending Data (cont.)*.

# %%
# Load dataset
df = pd.read_csv('winequality_edited.csv')
df.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality color
# 0      9.4        5   red
# 1      9.8        5   red
# ...

# %% [markdown]
# ### Histograms for Various Features
# A histogram is a graph that shows the frequency of numerical data using columns. The height of a column (the vertical axis) represents the distribution frequency of a variable (the amount, or how often that variable appears).

# %% [markdown]
# #### Based on histograms of columns in this dataset, which feature variables appear skewed to the right?
# #### Fixed Acidity, Total Sulfer Dioxide, pH, or Alcohol?

# %% [markdown]
# Write your answer here after drawing the required histograms

# %%
# Histogram of fiexed_acidity
df.fixed_acidity.hist();

# %%
# Histogram of total_sulfur_dioxide

# %%
# Histogram of pH

# %%
# Histogram of alcohol

# %%
df.hist(figsize= (15,12));  # histogram of whole dataset

# %% [markdown]
# ### Scatterplots of Quality Against Various Features
# A scatterplot is a type of data display that shows the relationship between two numerical variables. Each member of the dataset gets plotted as a point whose x-y coordinates relates to its values for the two variables.

# %% [markdown]
# #### Based on scatterplots of quality against different feature variables, which of the following is most likely to have a positive impact on quality?

# %% [markdown]
# Write your answer here

# %%
# scatterplot of volatile_acidity against quality
df.plot(x="volatile_acidity", y="quality", kind="scatter");

# %%
# scatterplot of residual_sugar against quality

# %%
# scatterplot of pH against quality

# %%
# scatterplot of alcohol against quality

# %%
# scatterplot of the whole dataset
pd.plotting.scatter_matrix(df, alpha=0.2, figsize = (15,15));

# %% [markdown]
# <a id='group_by'></a>
# # Drawing Conclusions Using Groupby

# %% [markdown]
# Use `winequality_edited.csv`. You should've created this data file in the previous section: *Appending Data (cont.)*.

# %% [markdown]
# ### Is a certain type of wine associated with higher quality?

# %%
# Find the mean quality of each wine type (red and white) with groupby
df.groupby('color').mean().quality
# Out:
# color
# red      5.636023
# white    5.877909
# Name: quality, dtype: float64

# %% [markdown]
# White wine has higher quality

# %% [markdown]
# ### What level of acidity receives the highest average rating?
# This question is more tricky because unlike color, which has clear categories you can group by (red and white), pH is a quantitative variable without clear categories. However, there is a simple fix to this. You can create a categorical variable from a quantitative variable by creating your own categories. pandas' `cut` function let's you "cut" data in groups.
#
# Using this, create a new column called acidity_levels with these categories:
#
# Acidity Levels:
#
# High: Lowest 25% of pH values
#
# Moderately High: 25% - 50% of pH values
#
# Medium: 50% - 75% of pH values
#
# Low: 75% - max pH value
#
# Here, the data is being split at the 25th, 50th, and 75th percentile. Remember, you can get these numbers with pandas' `describe()`!
#
# After you create these four categories, you'll be able to use groupby to get the mean quality rating for each acidity level.

# %%
# View the min, 25%, 50%, 75%, max pH values with Pandas' describe()

# %%
# Bin edges that will be used to "cut" the data into groups
bin_edges = [] # Fill in this list with five values you just found

# %%
# Labels for the four acidity level groups
bin_names = ['high', 'mod_high', 'medium', 'low'] # Name each acidity level category

# %%
# Creates acidity_levels column
df['acidity_levels'] = pd.cut(df['pH'], bin_edges, labels=bin_names)

# Checks for successful creation of this column
df.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality color acidity_levels
# 0      9.4        5   red            low
# ...

# %%
# Find the mean quality of each acidity level with groupby

# %% [markdown]
# Write your answer to the question here

# %%
# Save changes for the next section
df.to_csv('winequality_edited.csv', index=False)

# %% [markdown]
# <a id='query'></a>
# # Drawing Conclusions Using Query

# %% [markdown]
# ### Do wines with higher alcoholic content receive better ratings?

# %%
df.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality color acidity_levels
# 0      9.4        5   red            low
# ...

# %%
# get the median amount of alcohol content. Since data is skewed, it's better to use median over mean.
df.alcohol.median()
# Out:
# 10.3

# %%
# select samples with alcohol content less than the median
low_alcohol = df.query('alcohol < 10.3')    # Same results could be achieved by masking low_alcohol = df[df['alcohol'] <10.3]

# select samples with alcohol content greater than or equal to the median
high_alcohol = df.query('alcohol >= 10.3')

# ensure these queries included each sample exactly once
num_samples = df.shape[0]
num_samples == low_alcohol['quality'].count() + high_alcohol['quality'].count() # should be True
# Out:
# True

# %%
# get mean quality rating for the low alcohol and high alcohol groups
low_alcohol.quality.mean(), high_alcohol.quality.mean()
# Out:
# (5.475920679886686, 6.146084337349397)

# %% [markdown]
# Yes.

# %% [markdown]
# ### Do sweeter wines receive better ratings?

# %%
# get the median amount of residual sugar

# %%
# select samples with residual sugar less than the median
low_sugar = 

# select samples with residual sugar greater than or equal to the median
high_sugar = 


# ensure these queries included each sample exactly once

# %%
# get mean quality rating for the low sugar and high sugar groups
# Out:
# (5.808800743724822, 5.82782874617737)

# %% [markdown]
# Write your answer to the question here.

# %% [markdown]
# <a id='plt'></a>
# # Plotting with Matplotlib
# Use Matplotlib to create bar charts that visualize the conclusions you made with groupby and query.

# %% [markdown]
# ### 1: Do wines with higher alcoholic content receive better ratings?
# Create a bar chart with one bar for low alcohol and one bar for high alcohol wine samples. This first one is filled out for you.

# %%
# Use query to select each group and get its mean quality
median = df['alcohol'].median()
low = df.query('alcohol < {}'.format(median))
high = df.query('alcohol >= {}'.format(median))

mean_quality_low = low['quality'].mean()
mean_quality_high = high['quality'].mean()

# %%
# Create a bar chart with proper labels
locations = [1, 2]
heights = [mean_quality_low, mean_quality_high]
labels = ['Low', 'High']
plt.bar(locations, heights, tick_label=labels)
plt.title('Average Quality Ratings by Alcohol Content')
plt.xlabel('Alcohol Content')
plt.ylabel('Average Quality Rating');

# %% [markdown]
# ### 2: Do sweeter wines receive higher ratings?
# Create a bar chart with one bar for low residual sugar and one bar for high residual sugar wine samples.

# %%
# Use query to select each group and get its mean quality

# %%
# Create a bar chart with proper labels

# %% [markdown]
# ### 3: What level of acidity receives the highest average rating?
# Create a bar chart with a bar for each of the four acidity levels.

# %%
# Use groupby to get the mean quality for each acidity level
acidity_level_quality_means = df.groupby('acidity_levels').quality.mean()
acidity_level_quality_means
# Out:
# acidity_levels
# high        5.783343
# mod_high    5.784540
# medium      5.850832
# low         5.859593
# Name: quality, dtype: float64

# %%
# Create a bar chart with proper labels
locations = [4, 1, 2, 3]  # reorder values above to go from low to high
heights = acidity_level_quality_means

# labels = ['Low', 'Medium', 'Moderately High', 'High']
labels = acidity_level_quality_means.index.str.replace('_', ' ').str.title() # alternative to commented out line above

plt.bar(locations, heights, tick_label=labels)
plt.title('Average Quality Ratings by Acidity Level')
plt.xlabel('Acidity Level')
plt.ylabel('Average Quality Rating');

# %% [markdown]
# <a id='plt2'></a>
# # Plotting Wine Type and Quality with Matplotlib

# %% [markdown]
# ### Create arrays for red bar heights white bar heights
# Remember, there's a bar for each combination of color and quality rating. Each bar's height is based on the proportion of samples of that color with that quality rating.
# 1. Red bar proportions = counts for each quality rating / total # of red samples
# 2. White bar proportions = counts for each quality rating / total # of white samples

# %%
# get counts for each rating and color
color_counts = df.groupby(['color', 'quality']).count()['pH']
color_counts
# Out:
# color  quality
# red    3            10
#        4            53
#        5           681
#        6           638
#        7           199
#        8            18
# white  3            20
#        4           163
#        5          1457
#        6          2198
#        7           880
#        8           175
#        9             5
# Name: pH, dtype: int64

# %%
# get total counts for each color
color_totals = df.groupby('color').count()['pH']
color_totals
# Out:
# color
# red      1599
# white    4898
# Name: pH, dtype: int64

# %%
# get proportions by dividing red rating counts by total # of red samples
red_proportions = color_counts['red'] / color_totals['red']
red_proportions
# Out:
# quality
# 3    0.006254
# 4    0.033146
# 5    0.425891
# 6    0.398999
# 7    0.124453
# 8    0.011257
# Name: pH, dtype: float64

# %%
# get proportions by dividing white rating counts by total # of white samples
white_proportions =

# %% [markdown]
# ### Plot proportions on a bar chart
# Set the x coordinate location for each rating group and and width of each bar.

# %%
ind = np.arange(len(red_proportions))  # the x locations for the groups. We will need to change this later to len(white_proportions)
width = 0.35       # the width of the bars

# %%
len(red_proportions), len(white_proportions)
# Out:
# (6, 7)

# %%
ind
# Out:
# array([0, 1, 2, 3, 4, 5])

# %% [markdown]
# Now let’s create the plot.

# %%
# plot bars
red_bars = plt.bar(ind, red_proportions, width, color='r', alpha=.7, label='Red Wine')
white_bars = plt.bar(ind + width, white_proportions, width, color='w', alpha=.7, label='White Wine')

# title and labels
plt.ylabel('Proportion')
plt.xlabel('Quality')
plt.title('Proportion by Wine Color and Quality')
locations = ind + width / 2  # xtick locations
labels = ['3', '4', '5', '6', '7', '8', '9']  # xtick labels
plt.xticks(locations, labels)

# legend
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11424/1374811268.py in <module>
#       1 # plot bars
#       2 red_bars = plt.bar(ind, red_proportions, width, color='r', alpha=.7, label='Red Wine')
# ----> 3 white_bars = plt.bar(ind + width, white_proportions, width, color='w', alpha=.7, label='White Wine')
#       4
#       5 # title and labels
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2649         x, height, width=0.8, bottom=None, *, align='center',
#    2650         data=None, **kwargs):
# -> 2651     return gca().bar(
#    2652         x, height, width=width, bottom=bottom, align=align,
#    2653         **({"data": data} if data is not None else {}), **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
# ...

# %% [markdown]
# Oh, that didn't work because we're missing a red wine value for a the 9 rating. Even though this number is a 0, we need it for our plot. Run the last two cells after running the cell below.
#
# You also need to change "ind" value to `len(white_proportions)` to show all the 7 values of quality.

# %%
red_proportions['9'] = 0
red_proportions
# Out:
# quality
# 3    0.006254
# 4    0.033146
# 5    0.425891
# 6    0.398999
# 7    0.124453
# 8    0.011257
# 9    0.000000
# Name: pH, dtype: float64

# %%
# Change the value of ind using len(white_proportions)

ind =

# %%
# plot bars


# title and labels



# legend
